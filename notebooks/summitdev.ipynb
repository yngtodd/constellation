# %%
from hyperspace.kepler import load_results
from hyperspace.kepler.plots import plot_convergence

import matplotlib
import matplotlib.pyplot as plt
plt.style.use(['dark_background'])

# %matplotlib inline

# %%
plt.style
# Out:
# <module 'matplotlib.style' from '/Users/youngtodd/anaconda3/lib/python3.6/site-packages/matplotlib/style/__init__.py'>

# %%
cnn = '/Users/youngtodd/constellation/constellation/cnn/space5/results'

def objective():
    pass

# %%
results = load_results(cnn, sort=True)
top10 = [results[x] for x in range(10)]
one, two, three, four, five, six, seven, eight, nine, ten = top10
best = results.pop(0)

# %%
matplotlib.rcParams['figure.figsize'] = [15, 15]
#_ = plot_convergence(results, best)
_ = plot_convergence(results, one, two, three, four, five, six, seven, eight, nine, best)
